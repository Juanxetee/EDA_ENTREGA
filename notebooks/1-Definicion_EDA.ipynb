# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Hazte con el mejor!"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Pokémon"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "pokémon más popular a lo largo del tiempo"

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = "generacion pokemon que más gusta"
# hipotesis_3 = "relacion entre estadisticas y el tipo de pokemon"
# hipotesis_4 = "relación que tiene el cambio en la apariencia de los pokemon a lo largo del tiempo con su grado de aceptacion"
# hipotesis_5 = "tipo mas comun"
# hipotesis_6 =  'Rareza de los pokemon legendarios'
# hipotesis_7 = 'relacion 'tier list' con las caracteristicas del pokemon, solo los mejores tienen sitio en el competitivo?'

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
# Hacer una solicitud GET a la página web
url = 'https://vandal.elespanol.com/noticia/1350766721/estos-son-los-juegos-de-pokemon-mas-vendidos-de-todos-los-tiempos-cual-es-el-numero-1/'
respuesta = requests.get(url)

# Crear un objeto BeautifulSoup para analizar el HTML
soup = BeautifulSoup(respuesta.content, 'html.parser')

# Encontrar la tabla que contiene los datos
tabla = soup.find('table')

# Encontrar las etiquetas de encabezado de la tabla
encabezados = tabla.find_all('th')
nombres_columnas = [encabezado.text.strip() for encabezado in encabezados]

# Extraer las filas de la tabla
filas = tabla.find_all('tr')

# Crear una lista para almacenar los datos
datos = []

# Iterar sobre las filas y extraer los datos de las celdas
for fila in filas:
    celdas = fila.find_all('td')
    fila_datos = [celda.text.strip() for celda in celdas]
    datos.append(fila_datos)

# Crear un DataFrame con los datos extraídos y los nombres de las columnas
ventas = pd.DataFrame(datos[1:], columns=nombres_columnas)

# Mostrar el DataFrame
ventas
# Out:
#      #                                           Juego   Ańo  \
# 0    1                             Pokémon Rojo y Azul  1996
# 1    2                         Pokémon Espada y Escudo  2019
# 2    3                             Pokémon Oro y Plata  1999
# 3    4                     Pokémon Escarlata y Púrpura  2022
# 4    5                         Pokémon Diamond & Pearl  2006
# 5    6                                     Pokémon X/Y  2013
# 6    7                           Pokémon Rubí y Zafiro  2002
# 7    8                              Pokémon Sol y Luna  2016
# 8    9                  Pokémon Edición Negra y Blanca  2010
# 9   10  Pokémon: Let's Go, Pikachu! / Let's Go, Eevee!  2018
# 10  11   Pokémon Diamante Brillante / Perla Reluciente  2021
# 11  12                         Leyendas Pokémon Arceus  2022
# 12  13                                Pokémon Amarillo  1998
# 13  14                Pokémon Rubí Omega & Zafiro Alfa  2014
# 14  15              Pokémon Heart Gold and Soul Silver  2009
# 15  16                 Pokémon Rojo Fuego y Verde Hoja  2004
# 16  17                    Pokémon Ultrasol / Ultraluna  2017
# 17  18                Pokémon Edición Negra y Blanca 2  2012
# 18  19                                 Pokémon Platino  2008
# 19  20                                 Pokémon Cristal  2000
# 20  21                               Pokémon Esmeralda  2004
#
#    Ventas a nivel mundial        Plataforma
# 0          31,37 millones          Game Boy
# 1          26,02 millones   Nintendo Switch
# 2          23,73 millones    Game Boy Color
# 3          23,23 millones   Nintendo Switch
# 4          17,67 millones       Nintendo DS
# 5          16,45 millones      Nintendo 3DS
# 6          16,22 millones  Game Boy Advance
# 7          16,18 millones      Nintendo 3DS
# 8          15,64 millones       Nintendo DS
# 9          15,07 millones   Nintendo Switch
# 10         14,92 millones   Nintendo Switch
# 11         14,83 millones   Nintendo Switch
# 12         14,64 millones          Game Boy
# 13         14,27 millones      Nintendo 3DS
# 14         12,72 millones       Nintendo DS
# 15            12 millones  Game Boy Advance
# 16          8,77 millones      Nintendo 3DS
# 17          7,63 millones       Nintendo DS
# 18          7,06 millones       Nintendo DS
# 19          6,39 millones    Game Boy Color
# 20          6,32 millones  Game Boy Advance

# %%
import requests
from bs4 import BeautifulSoup
from simplejson import JSONDecodeError

# Hacer una solicitud GET a la página web
url = 'https://www.millenium.gg/noticias/32528.html'
respuesta = requests.request(url= url, method= 'GET')
# Crear un objeto BeautifulSoup para analizar el HTML
soup = BeautifulSoup(respuesta.text, 'lxml')

# Encontrar las etiquetas de encabezado de la tabla
encabezados = tabla.find_all('th')
nombres_columnas = [encabezado.text.strip() for encabezado in encabezados]

# Crear una lista para almacenar los datos
datos = []

# Iterar sobre las filas y extraer los datos de las celdas
for fila in filas:
    celdas = fila.find_all('td')
    fila_datos = [celda.text.strip() for celda in celdas]
    datos.append(fila_datos)

# Crear un DataFrame con los datos extraídos y los nombres de las columnas
df1 = pd.DataFrame(datos[1:], columns=nombres_columnas)

# Mostrar el DataFrame
df1
# Out:
#      #                                           Juego   Ańo  \
# 0    1                             Pokémon Rojo y Azul  1996
# 1    2                         Pokémon Espada y Escudo  2019
# 2    3                             Pokémon Oro y Plata  1999
# 3    4                     Pokémon Escarlata y Púrpura  2022
# 4    5                         Pokémon Diamond & Pearl  2006
# 5    6                                     Pokémon X/Y  2013
# 6    7                           Pokémon Rubí y Zafiro  2002
# 7    8                              Pokémon Sol y Luna  2016
# 8    9                  Pokémon Edición Negra y Blanca  2010
# 9   10  Pokémon: Let's Go, Pikachu! / Let's Go, Eevee!  2018
# 10  11   Pokémon Diamante Brillante / Perla Reluciente  2021
# 11  12                         Leyendas Pokémon Arceus  2022
# 12  13                                Pokémon Amarillo  1998
# 13  14                Pokémon Rubí Omega & Zafiro Alfa  2014
# 14  15              Pokémon Heart Gold and Soul Silver  2009
# 15  16                 Pokémon Rojo Fuego y Verde Hoja  2004
# 16  17                    Pokémon Ultrasol / Ultraluna  2017
# 17  18                Pokémon Edición Negra y Blanca 2  2012
# 18  19                                 Pokémon Platino  2008
# 19  20                                 Pokémon Cristal  2000
# 20  21                               Pokémon Esmeralda  2004
#
#    Ventas a nivel mundial        Plataforma
# 0          31,37 millones          Game Boy
# 1          26,02 millones   Nintendo Switch
# 2          23,73 millones    Game Boy Color
# 3          23,23 millones   Nintendo Switch
# 4          17,67 millones       Nintendo DS
# 5          16,45 millones      Nintendo 3DS
# 6          16,22 millones  Game Boy Advance
# 7          16,18 millones      Nintendo 3DS
# 8          15,64 millones       Nintendo DS
# 9          15,07 millones   Nintendo Switch
# 10         14,92 millones   Nintendo Switch
# 11         14,83 millones   Nintendo Switch
# 12         14,64 millones          Game Boy
# 13         14,27 millones      Nintendo 3DS
# 14         12,72 millones       Nintendo DS
# 15            12 millones  Game Boy Advance
# 16          8,77 millones      Nintendo 3DS
# 17          7,63 millones       Nintendo DS
# 18          7,06 millones       Nintendo DS
# 19          6,39 millones    Game Boy Color
# 20          6,32 millones  Game Boy Advance

# %%
import csv 
import seaborn as sns
import pandas as pd

pokemon = pd.read_csv('pokemon.csv')
pokemon2 = pd.read_csv('Pokemon_alopez247.csv')
pokemon
# Out:
#       number                  name    type1   type2  total   hp  attack  \
# 0          1             Bulbasaur    Grass  Poison    318   45      49
# 1          2               Ivysaur    Grass  Poison    405   60      62
# 2          3              Venusaur    Grass  Poison    525   80      82
# 3          3         Mega Venusaur    Grass  Poison    625   80     100
# 4          3   Gigantamax Venusaur    Grass  Poison    525   80      82
# ...      ...                   ...      ...     ...    ...  ...     ...
# 1067     896             Glastrier      Ice     NaN    580  100     145
# 1068     897             Spectrier    Ghost     NaN    580  100      65
# 1069     898               Calyrex  Psychic   Grass    500  100      80
# 1070     898     Ice Rider Calyrex  Psychic     Ice    680  100     165
# 1071     898  Shadow Rider Calyrex  Psychic   Ghost    680  100      85
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# 0          49         65          65     45           1      False
# 1          63         80          80     60           1      False
# 2          83        100         100     80           1      False
# 3         123        122         120     80           1      False
# 4          83        100         100     80           1      False
# ...       ...        ...         ...    ...         ...        ...
# 1067      130         65         110     30           8       True
# 1068       60        145          80    130           8       True
# 1069       80         80          80     80           8       True
# 1070      150         85         130     50           8       True
# 1071       80        165         100    150           8       True
#
# [1072 rows x 13 columns]

# %%
pokemon2
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 0        65  ...   Green       True    0.875       Monster        Grass
# 1        80  ...   Green       True    0.875       Monster        Grass
# 2       100  ...   Green       True    0.875       Monster        Grass
# 3        50  ...     Red       True    0.875       Monster       Dragon
# 4        65  ...     Red       True    0.875       Monster       Dragon
# ..      ...  ...     ...        ...      ...           ...          ...
# 716      98  ...     Red      False      NaN  Undiscovered          NaN
# 717      95  ...   Green      False      NaN  Undiscovered          NaN
# 718     150  ...    Pink      False      NaN  Undiscovered          NaN
# 719     130  ...  Purple      False      NaN  Undiscovered          NaN
# 720      90  ...   Brown      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate       Body_Style
# 0               False     0.71       6.9          45        quadruped
# 1               False     0.99      13.0          45        quadruped
# 2                True     2.01     100.0          45        quadruped
# 3               False     0.61       8.5          45   bipedal_tailed
# 4               False     1.09      19.0          45   bipedal_tailed
# ..                ...      ...       ...         ...              ...
# 716             False     5.79     203.0          45        two_wings
# 717             False     5.00     305.0           3  serpentine_body
# 718              True     0.71       8.8           3        head_arms
# 719             False     0.51       9.0           3        head_only
# 720             False     1.70     195.0           3        quadruped
#
# [721 rows x 23 columns]

# %%
import pandas as pd
from pokepy import V2Client

# Crear un cliente pokepy
client = V2Client()

# Lista para almacenar los datos de los Pokémon
datos_pokemon = []

# Iterar sobre todos los Pokémon (ID 1 a 898)
for id_pokemon in range(1, 899):
    # Obtener información sobre el Pokémon actual
    pokemon_lista = client.get_pokemon(id_pokemon)
    
    # Iterar sobre la lista de Pokémon obtenida
    for pokemon in pokemon_lista:
        # Extraer los datos relevantes del Pokémon
        datos_pokemon.append({
            "ID": pokemon.id,
            "Nombre": pokemon.name,
            "Altura": pokemon.height,
            "Peso": pokemon.weight,
            "Tipos": [tipo.type.name for tipo in pokemon.types],
            "Habilidades": [habilidad.ability.name for habilidad in pokemon.abilities],
            "Estadisticas": {
                stat.stat.name: stat.base_stat for stat in pokemon.stats
            },
            "Movimientos": [movimiento.move.name for movimiento in pokemon.moves]
        })

# Crear un DataFrame con los datos de los Pokémon
df_pokemon = pd.DataFrame(datos_pokemon)

# Mostrar las primeras filas del DataFrame
df_pokemon
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 13
#      10 # Iterar sobre todos los Pokémon (ID 1 a 898)
#      11 for id_pokemon in range(1, 899):
#      12     # Obtener información sobre el Pokémon actual
# ---> 13     pokemon_lista = client.get_pokemon(id_pokemon)
#      15     # Iterar sobre la lista de Pokémon obtenida
#      16     for pokemon in pokemon_lista:
#      17         # Extraer los datos relevantes del Pokémon
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\pokepy\beckett_tweaks.py:41, in BaseClient._assign_method.<locals>.get(self, uid, method_type, method_name, valid_status_codes, resource, data, **kwargs)
#      37 def get(self, uid=None, method_type=method_type,
#      38         method_name=method_name,
#      39         valid_status_codes=valid_status_codes,
#      40         resource=resource_class, data=None, **kwargs):
# ---> 41     return self.call_api(
#      42         method_type, method_name,
#      43         valid_status_codes, resource,
#      44         data, uid=uid, **kwargs)
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\beckett\clients.py:98, in HTTPClient.call_api(self, method_type, method_name, valid_status_codes, resource, data, uid, **kwargs)
#      95     params.update(json=data)
#      96 prepared_request = self.prepare_http_request(
#      97     method_type, params, **kwargs)
# ---> 98 response = self.session.send(prepared_request)
#      99 return self._handle_response(response, valid_status_codes, resource)
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\response.py:1033, in HTTPResponse.stream(self, amt, decode_content)
#    1031 else:
#    1032     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1033         data = self.read(amt=amt, decode_content=decode_content)
#    1035         if data:
#    1036             yield data
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\response.py:946, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     940         raise RuntimeError(
#     941             "Calling read(decode_content=False) is not supported after "
#     942             "read(decode_content=True) was called."
#     943         )
#     944     return data
# --> 946 decoded_data = self._decode(data, decode_content, flush_decoder)
#     947 self._decoded_buffer.put(decoded_data)
#     949 while len(self._decoded_buffer) < amt and data:
#     950     # TODO make sure to initially read enough data to get past the headers
#     951     # For example, the GZ file header takes 10 bytes, we don't want to read
#     952     # it one byte at a time
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\response.py:472, in BaseHTTPResponse._decode(self, data, decode_content, flush_decoder)
#     470 try:
#     471     if self._decoder:
# --> 472         data = self._decoder.decompress(data)
#     473         self._has_decoded_content = True
#     474 except self.DECODER_ERROR_CLASSES as e:
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\response.py:128, in GzipDecoder.decompress(self, data)
#     126 while True:
#     127     try:
# --> 128         ret += self._obj.decompress(data)
#     129     except zlib.error:
#     130         previous_state = self._state
#
# KeyboardInterrupt:

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_pokemon = pd.DataFrame(df_pokemon)
fuente_1 = "https://pokeapi.co/"
df_2 = pd.read_csv('pokemons2.csv')
fuente_2 = "https://www.kaggle.com/datasets/bhavyadhingra00020/complete-pokemon-dataset-9th-gen-img-tabular"
df_3 = ventas
fuente_3 = "'https://vandal.elespanol.com/noticia/1350766721/estos-son-los-juegos-de-pokemon-mas-vendidos-de-todos-los-tiempos-cual-es-el-numero-1/'"
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()
